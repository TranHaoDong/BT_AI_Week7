# %% [markdown]
# <a href="https://colab.research.google.com/github/TranHaoDong/BT_AI_Week7/blob/main/Salary_Data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sas

url = 'Salary_Data.csv'
data= pd.read_csv(url)

data.head()
# Out:
#    YearsExperience   Salary
# 0              1.1  39343.0
# 1              1.3  46205.0
# 2              1.5  37731.0
# 3              2.0  43525.0
# 4              2.2  39891.0

# %%
sas.pairplot(data)

# %%
correlation = data.corr()
sas.heatmap(correlation, annot = True)
# Out:
# <Axes: >

# %%
data.plot(kind= 'scatter', x = 'YearsExperience', y = 'Salary', figsize = (6 , 6), color = 'green')
# Out:
# /usr/local/lib/python3.9/dist-packages/pandas/plotting/_matplotlib/core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(
# <Axes: xlabel='YearsExperience', ylabel='Salary'>

# %%
from sklearn import linear_model
model = linear_model.LinearRegression()
model.fit(X = pd.DataFrame(data['Salary']), y= data['YearsExperience'])
print(model.intercept_)
print(model.coef_)
# Out:
# -2.3831605648243537
# [0.00010127]

# %%
#Do chinh xac
model.score(X = pd.DataFrame(data['Salary']), y= data['YearsExperience'])
# Out:
# 0.9569566641435086

# %%
#Mo hinh bac 1
data.plot(kind= 'scatter', x = 'Salary', y= 'YearsExperience', figsize = (5,5), color = 'red')
y_pred = model.predict(X = pd.DataFrame(data['Salary']))
plt.plot(data['Salary'], y_pred, color = 'blue')
# Out:
# /usr/local/lib/python3.9/dist-packages/pandas/plotting/_matplotlib/core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(

# %%
#Mo hinh bac 2
model = linear_model.LinearRegression()
X = pd.DataFrame([data['Salary'], data['Salary']**2]).T
model.fit(X, y= data['YearsExperience'])
print('Intercept cua mo hinh:', model.intercept_)
print('Coefficient cua mo hinh', model.coef_)
print('Do chinh xac cua mo hinh', model.score(X, y = data['YearsExperience']))

#Ve do thi mo hinh bac 2
import numpy as np
range = np.arange(0,150000,10)
data.plot(kind= 'scatter', x = 'Salary', y= 'YearsExperience', figsize = (5,5), color = 'red')
predictor = pd.DataFrame([range, range**2]).T
y_pred = model.predict(X = predictor)
plt.plot(range, y_pred, color = 'green')
# Out:
# Intercept cua mo hinh: -1.7159926410950517
# Coefficient cua mo hinh [8.25400952e-05 1.16259621e-10]
# Do chinh xac cua mo hinh 0.9575102146552049
# /usr/local/lib/python3.9/dist-packages/pandas/plotting/_matplotlib/core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(
# /usr/local/lib/python3.9/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
#Mo hinh bac 3
model = linear_model.LinearRegression()
X = pd.DataFrame([data['Salary'], data['Salary']**2, data['Salary']**3]).T
model.fit(X, y= data['YearsExperience'])
print('Intercept cua mo hinh:', model.intercept_)
print('Coefficient cua mo hinh', model.coef_)
print('Do chinh xac cua mo hinh', model.score(X, y = data['YearsExperience']))
#Ve do thi mo hinh bac 3
import numpy as np
range = np.arange(1.5,120000,10)
data.plot(kind= 'scatter', x = 'Salary', y= 'YearsExperience', figsize = (5,5), color = 'red')
predictor = pd.DataFrame([range, range**2, range**3]).T
y_pred = model.predict(X = predictor)
plt.plot(range, y_pred, color = 'green')
# Out:
# Intercept cua mo hinh: -6.193134376067245
# Coefficient cua mo hinh [ 2.78222615e-04 -2.53776109e-09  1.12287280e-14]
# Do chinh xac cua mo hinh 0.9607554847155427
# /usr/local/lib/python3.9/dist-packages/pandas/plotting/_matplotlib/core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(
# /usr/local/lib/python3.9/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
#Mo hinh bac 4
model = linear_model.LinearRegression()
X = pd.DataFrame([data['Salary'], data['Salary']**2, data['Salary']**3, data['Salary']**4]).T
model.fit(X, y= data['YearsExperience'])
print('Intercept cua mo hinh:', model.intercept_)
print('Coefficient cua mo hinh', model.coef_)
print('Do chinh xac cua mo hinh', model.score(X, y = data['YearsExperience']))
#Ve do thi mo hinh bac 4
import numpy as np
range = np.arange(1.5,120000,10)
data.plot(kind= 'scatter', x = 'Salary', y= 'YearsExperience', figsize = (5,5), color = 'red')
predictor = pd.DataFrame([range, range**2, range**3, range**4]).T
y_pred = model.predict(X = predictor)
plt.plot(range, y_pred, color = 'green')
# Out:
# Intercept cua mo hinh: -1.3927189736991634
# Coefficient cua mo hinh [ 6.53175494e-14  3.16161735e-09 -3.78828179e-14  1.51370743e-19]
# Do chinh xac cua mo hinh 0.9602619959752623
# /usr/local/lib/python3.9/dist-packages/pandas/plotting/_matplotlib/core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(
# /usr/local/lib/python3.9/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
#Mo hinh bac 5
model = linear_model.LinearRegression()
X = pd.DataFrame([data['Salary'], data['Salary']**2, data['Salary']**3, data['Salary']**4, data['Salary']**5] ).T
model.fit(X, y= data['YearsExperience'])
print('Intercept cua mo hinh:', model.intercept_)
print('Coefficient cua mo hinh', model.coef_)
print('Do chinh xac cua mo hinh', model.score(X, y = data['YearsExperience']))
#Ve do thi mo hinh bac 5
import numpy as np
range = np.arange(1.5,120000,10)
data.plot(kind= 'scatter', x = 'Salary', y= 'YearsExperience', figsize = (5,5), color = 'red')
predictor = pd.DataFrame([range, range**2, range**3, range**4, range**5]).T
y_pred = model.predict(X = predictor)
plt.plot(range, y_pred, color = 'green')
# Out:
# Intercept cua mo hinh: 0.22803124445431688
# Coefficient cua mo hinh [ 1.57219546e-23  2.11703211e-18  4.35152941e-14 -5.98021785e-19
#   2.35657717e-24]
# Do chinh xac cua mo hinh 0.9582897205522598
# /usr/local/lib/python3.9/dist-packages/pandas/plotting/_matplotlib/core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(
# /usr/local/lib/python3.9/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
#Mo hinh bac 6
model = linear_model.LinearRegression()
X = pd.DataFrame([data['Salary'], data['Salary']**2, data['Salary']**3, data['Salary']**4, data['Salary']**5, data['Salary']**6]).T
model.fit(X, y= data['YearsExperience'])
print('Intercept cua mo hinh:', model.intercept_)
print('Coefficient cua mo hinh', model.coef_)
print('Do chinh xac cua mo hinh', model.score(X, y = data['YearsExperience']))
#Ve do thi mo hinh bac 6
import numpy as np
range = np.arange(1.5,120000,10)
data.plot(kind= 'scatter', x = 'Salary', y= 'YearsExperience', figsize = (5,5), color = 'red')
predictor = pd.DataFrame([range, range**2, range**3, range**4, range**5, range**6]).T
y_pred = model.predict(X = predictor)
plt.plot(range, y_pred, color = 'green')
# Out:
# Intercept cua mo hinh: 1.1519713212623879
# Coefficient cua mo hinh [ 3.20520214e-33 -1.00538395e-23  1.63535258e-23  5.82668586e-19
#  -8.60874841e-24  3.42495148e-29]
# Do chinh xac cua mo hinh 0.9534915811013813
# /usr/local/lib/python3.9/dist-packages/pandas/plotting/_matplotlib/core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(
# /usr/local/lib/python3.9/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
#Mô Hình bậc 4 có dộ chính xác cao nhất
